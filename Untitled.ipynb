# %%
import sys
sys.path.append('C:/ProgramData/Anaconda3/Lib/site-packages')
import yaml
import json
with open('D:/PYT/testconfigs.json', encoding='utf-8') as f:
    jsondata = json.load(f)
with open('D:/PYT/testconfigs.yaml', 'w') as w:
    w.write(yaml.dump(jsondata))
